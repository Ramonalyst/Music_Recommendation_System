# %%
import pandas as pd
import plotly.express as px
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from google.cloud import bigquery
import pandas as pd
from google.oauth2 import service_account

import pyarrow.parquet as pq

# %%
# Connect to BQ

credentials = service_account.Credentials.from_service_account_file(
'/Users/mariegeorgescudehillerin/Desktop/Le Wagon/Project/music-recommendation-system-24-e7b0bc87bbb3.json')
# music-recommendation-system-24-3d0d21fb1f8b.json is the service account JSON file. Save the file locally on your device and add the path here.
# make sure that the slashes in the path are '/' and not '\'

project_id = 'music-recommendation-system-24'
client = bigquery.Client(credentials= credentials,project=project_id)

# %%
# Query BQ

query_job = client.query("""
   SELECT
      *
   FROM `music-recommendation-system-24.ml_tables_eu.spotify_songs_obama_concat_csv_V0`""")
#put the query in three quote marks


results = query_job.result() # Wait for the job to complete.

rows = [dict(row) for row in results]

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(rows)

# %%
df.head()
# Out:
#    is_in_obama_playlist                track_id  \
# 0                     1  0UZFhlhUMrYyzzyOHkylM3
# 1                     1  3aEJMh1cXKEjgh52claxQp
# 2                     0  6qb0O5HW7H4q6R0AbP38Ko
# 3                     1  6nKeLkmlyK3ooDoDUxZVgP
# 4                     1  4smkJW6uzoHxGReZqqwHS5
#
#                                      track_name  \
# 0                                Let's Get Lost
# 1  I've Got You Under My Skin - Remastered 1998
# 2                   Long Tall Sally (The Thing)
# 3                                     Lush Life
# 4                            I'll Be Seeing You
#
#                                     track_album_name  \
# 0       Chet Baker Sings And Plays (Remastered 2004)
# 1            Songs For Swingin' Lovers! (Remastered)
# 2      Here's Little Richard [Remastered & Expanded]
# 3  Ella Fitzgerald Sings The Duke Ellington Song ...
# 4                                     Billie Holiday
#
#                      track_artist  track_popularity  track_album_release_year  \
# 0                      Chet Baker                52                      1955
# 1                   Frank Sinatra                66                      1956
# 2                  Little Richard                 1                      1957
# 3  Ella Fitzgerald,Oscar Peterson                18                      1957
# 4                  Billie Holiday                67                      1957
#
#   genre  duration_min  danceability  energy key  loudness   mode  speechiness  \
# 0  Jazz          3.73          52.0   37.00   C    -9.350  Major         3.00
# 1  Jazz          3.73          58.0   25.00  C#   -12.610  Major         4.00
# 2  rock          2.20          47.4   59.80   F    -5.023  Major         9.73
# 3  Jazz          3.67          40.0    4.38  A#   -19.260  Major         3.91
# 4  Jazz          3.53          36.0    3.00  C#   -20.480  Major         4.00
#
#    acousticness  instrumentalness  liveness  valence  tempo
# 0          84.0               0.0     11.00     55.0     78
# 1          45.0               0.0     11.00     59.0    127
# 2          76.8               0.0      8.41     91.7    184
# 3          97.4               0.0      8.95     17.6     91
# 4          99.0               6.0     12.00     19.0     90

# %%
df.drop(columns=["track_id", "track_name", "track_album_name"])
# Out:
#        is_in_obama_playlist                                track_artist  \
# 0                         1                                  Chet Baker
# 1                         1                               Frank Sinatra
# 2                         0                              Little Richard
# 3                         1              Ella Fitzgerald,Oscar Peterson
# 4                         1                              Billie Holiday
# ...                     ...                                         ...
# 32999                     1                       Tyla,Gunna,Skillibeng
# 33000                     1                                 Myles Smith
# 33001                     1  Chris Jedi,Gaby Music,Dei V,Anuel AA,Ozuna
# 33002                     1                               Tommy Richman
# 33003                     1                                        Tems
#
#        track_popularity  track_album_release_year      genre  duration_min  \
# 0                    52                      1955       Jazz          3.73
# 1                    66                      1956       Jazz          3.73
# 2                     1                      1957       rock          2.20
# 3                    18                      1957       Jazz          3.67
# 4                    67                      1957       Jazz          3.53
# ...                 ...                       ...        ...           ...
# 32999                69                      2024    Hip Hop          2.45
# 33000                89                      2024        Pop          2.88
# 33001                59                      2024  Reggaeton          3.92
# 33002                90                      2024    Hip Hop          2.59
# 33003                72                      2024  Afrobeats          2.97
#
#        danceability  energy key  loudness   mode  speechiness  acousticness  \
# 0              52.0   37.00   C    -9.350  Major         3.00          84.0
# 1              58.0   25.00  C#   -12.610  Major         4.00          45.0
# 2              47.4   59.80   F    -5.023  Major         9.73          76.8
# 3              40.0    4.38  A#   -19.260  Major         3.91          97.4
# 4              36.0    3.00  C#   -20.480  Major         4.00          99.0
# ...             ...     ...  ..       ...    ...          ...           ...
# 32999          79.0   72.00  A#    -3.450  minor         9.00           3.0
# 33000          64.0   60.00  C#    -6.130  minor         3.00          25.0
# 33001          77.0   71.00  C#    -4.890  minor         8.00          33.0
# 33002          85.0   70.00  C#    -5.520  minor         4.00          10.0
# 33003          83.0   52.00  G#   -10.870  minor        14.00          16.0
#
#        instrumentalness  liveness  valence  tempo
# 0                   0.0     11.00     55.0     78
# 1                   0.0     11.00     59.0    127
# 2                   0.0      8.41     91.7    184
# 3                   0.0      8.95     17.6     91
# 4                   6.0     12.00     19.0     90
# ...                 ...       ...      ...    ...
# 32999               0.0     21.00     63.0    100
# 33000               0.0     11.00     33.0    124
# 33001               0.0     42.00     63.0     95
# 33002               0.0      7.00     92.0    138
# 33003              53.0     11.00     53.0    104
#
# [33004 rows x 17 columns]
